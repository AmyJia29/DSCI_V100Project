# %% [markdown]
# # Data Science Project: Planning Stage (Individual)
# ## Problem: Predicting Usage of a Video Game Research Server
#
# Board Question: What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?
#
# Research Question: **Can player's experience level, age, gender and playtime predict whether a player subscribes to the newsletter?**
#
# Response variable:
# - subscribe (logical) from players.csv, which indicates whether the player subscribed to newsletter or not
#
# Predictor variables:
# - experience (categorical) from players.csv, which indicates player's experience level
# - gender (categorical) from players.csv, which indicates player's gender identity
# - age (numeric) from players.csv, which indicates player's age in years
# - played_hours (numeric) from players.csv, which indicates total hours the player spent in the game

# %% [markdown]
# ### Preprocessing and Exploratory Data Analysis

# %% [markdown]
# #### Importing libraries and formatting graphs

# %%
# loading necessary packages
library(tidyverse)
library(lubridate)
library(knitr)
library(ggplot2)
library(scales)
library(dplyr)
library(readr)

# formatting graphs
options(repr.plot.width = 10, repr.plot.height = 6)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor

# %% [markdown]
# #### Importing the dataset

# %% [markdown]
# ##### We used read_csv to import the players.csv and sessions.csv datasets from the working directory.

# %%
# loading datasets
players <- read_csv("players.csv")
sessions <- read_csv("sessions.csv")
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ### Data Exploration

# %%
# check dimensions
cat("=== DATASET OVERVIEW ===\n")
cat("Players dataset:", nrow(players), "rows and", ncol(players), "columns\n")
cat("Sessions dataset:", nrow(sessions), "rows and", ncol(sessions), "columns\n")
# Out:
# === DATASET OVERVIEW ===
# Players dataset: 196 rows and 7 columns
# Sessions dataset: 1535 rows and 5 columns

# %% [markdown]
# #### Data Description-players dataset

# %%
# display first few rows
head(players)

# summary of the dataset structure
cat("\nDataset Structure:\n")
glimpse(players)
# Out:
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e  0.1
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977  0.0
#   name      gender Age
# 1 Morgan    Male    9
# 2 Christian Male   17
# 3 Blake     Male   17
# 4 Flora     Female 21
# 5 Kylie     Male   21
# 6 Adrian    Female 17
# Dataset Structure:
# Rows: 196
# Columns: 7
# $ experience   <chr> "Pro", "Veteran", "Veteran", "Amateur", "Regular", "Amate…
# ...

# %%
cat("=== PLAYERS DATASET DESCRIPTION ===\n\n")

# variable descriptions and types
cat("\n--- Variable Descriptions ---\n\n")
cat("1. experience: Player's experience level\n")
cat(" - Levels: Beginner, Amateur, Regular, Veteran, Pro\n")
cat(" - Type: Character (Categorical)\n")
cat(" - This is our predictor variable\n\n")

cat("2. subscribe: Whether player subscribed to newsletter or not\n")
cat(" - Values: TRUE (subscribed), FALSE (not subscribed)\n")
cat(" - Type: Logical\n")
cat(" - This is our response variable\n\n")

cat("3. hashedEmail: Unique anonymized identifier for each player\n")
cat(" - Type: Character\n")
cat(" - Links to sessions dataset\n\n")

cat("4. played_hours: Total hours the player spent in the game\n")
cat(" - Type: Double (numeric)\n")
cat(" - Range: 0 to", max(players$played_hours, na.rm = TRUE), "hours\n")
cat(" - This is our predictor variable\n\n")

cat("5. name: Player's name\n")
cat(" - Type: Character\n\n")

cat("6. gender: Player's gender identity\n")
cat(" - Type: Character (Categorical)\n")
cat(" - This is our predictor variable\n\n")

cat("7. Age: Player's age in years\n")
cat(" - Type: Double (numeric)\n")
cat(" - Contains missing values (NA)\n")
cat(" - This is our predictor variable\n\n")
# Out:
# === PLAYERS DATASET DESCRIPTION ===
#
#
# --- Variable Descriptions ---
#
# 1. experience: Player's experience level
#  - Levels: Beginner, Amateur, Regular, Veteran, Pro
#  - Type: Character (Categorical)
#  - This is our predictor variable
#
# 2. subscribe: Whether player subscribed to newsletter or not
#  - Values: TRUE (subscribed), FALSE (not subscribed)
#  - Type: Logical
#  - This is our response variable
#
# 3. hashedEmail: Unique anonymized identifier for each player
#  - Type: Character
#  - Links to sessions dataset
#
# 4. played_hours: Total hours the player spent in the game
#  - Type: Double (numeric)
#  - Range: 0 to 223.1 hours
#  - This is our predictor variable
#
# 5. name: Player's name
#  - Type: Character
#
# 6. gender: Player's gender identity
#  - Type: Character (Categorical)
#  - This is our predictor variable
#
# 7. Age: Player's age in years
#  - Type: Double (numeric)
#  - Contains missing values (NA)
#  - This is our predictor variable

# %% [markdown]
# #### Summary Statistics for Players dataset

# %%
# checking for missing values
cat("\nMissing values in each column:\n")
colSums(is.na(players))

# checking for unique values in categorical variables
cat("\nExperience levels:", unique(players$experience), "\n")
cat("\nGender status:", unique(players$gender), "\n")
cat("\nSubscription status:", table(players$subscribe), "\n")
# Out:
# Missing values in each column:
#   experience    subscribe  hashedEmail played_hours         name       gender
#            0            0            0            0            0            0
#          Age
#            2
# Experience levels: Pro Veteran Amateur Regular Beginner
#
# Gender status: Male Female Non-binary Prefer not to say Agender Two-Spirited Other
#
# Subscription status: 52 144

# %%
cat("\n=== SUMMARY STATISTICS ===\n\n")

# summary statistics for numeric variables
cat("\n--- Numeric Variables Summary Table ---\n\n")

# calculate statistics for played_hours and age and create a summary table
summary_table <- data.frame(
    Variable = c("played_hours", "Age"),
    Mean = c(round(mean(players$played_hours, na.rm = TRUE),2),
             round(mean(players$Age, na.rm = TRUE),2)),
    Median = c(round(median(players$played_hours, na.rm = TRUE),2),
               round(median(players$Age, na.rm = TRUE),2)),
    SD = c(round(sd(players$played_hours, na.rm = TRUE),2),
           round(sd(players$Age, na.rm = TRUE),2)),
    Min = c(round(min(players$played_hours, na.rm = TRUE),2),
            round(min(players$Age, na.rm = TRUE),2)),
    Max = c(round(max(players$played_hours, na.rm = TRUE),2),
            round(max(players$Age, na.rm = TRUE),2)),
    Missing_values = c(sum(is.na(players$played_hours)),
                       sum(is.na(players$Age))))
print(summary_table)
cat("\n")

# table of mean values for all quantitative variables
numeric_summary <- players |>
summarise(mean_played_hours = round(mean(played_hours, na.rm = TRUE), 2),
          mean_age = round(mean(Age, na.rm = TRUE), 2))

cat("Table of Mean Values:\n")
print(numeric_summary)
cat("\n")

# summary for categorical variables
cat("\n--- Categorical Variables Summary ---\n\n")

# experience levels
cat("Experience Distribution:\n")
experience_table <- as.data.frame(table(players$experience))
colnames(experience_table) <- c("Experience Level", "Count")
print(experience_table)
cat("\n")

# subscription status (our response variable)
cat("Subscription Distribution:\n")
subscription_table <- as.data.frame(table(players$subscribe))
colnames(subscription_table) <- c("Subscription Status", "Count")
print(subscription_table)
cat(" Subscription rate:",
    round(mean(players$subscribe)*100, 2), "%\n\n")

# gender distribution
cat("Gender Distribution:\n")
gender_table <- as.data.frame(table(players$gender))
colnames(gender_table) <- c("Gender","Count")
print(gender_table)
cat("\n")
# Out:
# === SUMMARY STATISTICS ===
#
#
# --- Numeric Variables Summary Table ---
#
#       Variable  Mean Median    SD Min   Max Missing_values
# 1 played_hours  5.85    0.1 28.36   0 223.1              0
# 2          Age 21.14   19.0  7.39   9  58.0              2
#
# Table of Mean Values:
# # A tibble: 1 × 2
#   mean_played_hours mean_age
#               <dbl>    <dbl>
# 1              5.85     21.1
#
#
# --- Categorical Variables Summary ---
#
# Experience Distribution:
#   Experience Level Count
# 1          Amateur    63
# 2         Beginner    35
# 3              Pro    14
# 4          Regular    36
# 5          Veteran    48
#
# Subscription Distribution:
#   Subscription Status Count
# 1               FALSE    52
# 2                TRUE   144
#  Subscription rate: 73.47 %
#
# Gender Distribution:
#              Gender Count
# 1           Agender     2
# 2            Female    37
# 3              Male   124
# 4        Non-binary    15
# 5             Other     1
# ...

# %% [markdown]
# #### Potential Issues
# - The Age variable contains NA, which are missing values.
# - For the gender categories, there are multiple categories with small sample sizes.
# - There might be some outliers as played_hours ranges from 0 to ... hours and some players have 200+ hours, which may indicate highly engaged hours.

# %% [markdown]
# #### Data Description-sessions dataset

# %%
# display first few rows
head(players)

# summary of the dataset structure
cat("\nDataset Structure:\n")
glimpse(sessions)
# Out:
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e  0.1
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977  0.0
#   name      gender Age
# 1 Morgan    Male    9
# 2 Christian Male   17
# 3 Blake     Male   17
# 4 Flora     Female 21
# 5 Kylie     Male   21
# 6 Adrian    Female 17
# Dataset Structure:
# Rows: 1,535
# Columns: 5
# $ hashedEmail         <chr> "bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8a…
# ...

# %%
cat("=== SESSIONS DATASET DESCRIPTION ===\n\n")

# variable descriptions and types
cat("\nSessions Dataset Variables:\n")
cat("1. hashedEmail: Links to players dataset\n")
cat("2. start_time: Session start timestamp\n")
cat("3. end_time: Session end timestamp\n")
cat("4. original_start_time: Original start time in numeric format\n")
cat("5. original_end_time: Original end time in numeric format\n\n")
# Out:
# === SESSIONS DATASET DESCRIPTION ===
#
#
# Sessions Dataset Variables:
# 1. hashedEmail: Links to players dataset
# 2. start_time: Session start timestamp
# 3. end_time: Session end timestamp
# 4. original_start_time: Original start time in numeric format
# 5. original_end_time: Original end time in numeric format

# %% [markdown]
# This dataset can be used to calculate:
# Number of sessions per player,
# Patterns of session durations,
# Playing frequency

# %% [markdown]
# ### Data Wrangling

# %%
cat("=== DATA WRANGLING PLAN ===")
# create a clean version of the dataset for modeling
players_clean <- players |>
select(hashedEmail, subscribe, experience, Age, gender, played_hours) |>
mutate(
    subscribe = factor(subscribe, levels = c("FALSE", "TRUE")),
    experience = factor(experience, 
                        levels = c("Beginner", "Amateur", "Regular", "Veteran", "Pro"),
                        ordered = TRUE))
cat("Cleaned dataset preview:\n")
head(players_clean)
cat("\n")
cat("Cleaned dataset has", 
    nrow(players_clean), 
    ncol(players_clean), 
    "variables\n\n")
# Out:
# === DATA WRANGLING PLAN ===Cleaned dataset preview:
#   hashedEmail                                                      subscribe
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d TRUE
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9 TRUE
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28 FALSE
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5 TRUE
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e TRUE
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977 TRUE
#   experience Age gender played_hours
# 1 Pro         9  Male   30.3
# 2 Veteran    17  Male    3.8
# 3 Veteran    17  Male    0.0
# 4 Amateur    21  Female  0.7
# 5 Regular    21  Male    0.1
# 6 Amateur    17  Female  0.0
# Cleaned dataset has 196 6 variables

# %% [markdown]
# ### Exploratory Data Visualization

# %% [markdown]
# #### Visualization 1: Subscription Rate by Experience Level

# %%
ggplot(players, aes(x=experience, fill=subscribe))+
geom_bar(position="fill")+
labs(title="Newsletter Subscription Rate by Experience Level",
     x="Experience Level",
     y="Percentage",
     fill="Subscribed")
# Out:
# plot without title

# %% [markdown]
# ##### We group by experience to see whether experience level influences subscription. Bar plots show differences in subscription rates across ordered categories, helping us assess if experience is a strong predictor.

# %% [markdown]
# #### Visualization 2: Subscription Rate by Age

# %%
ggplot(players|>filter(!is.na(Age)),
       aes(x=Age, fill=subscribe))+
geom_histogram(bins=20, alpha=0.7, position="identity")+
facet_wrap(~subscribe, ncol=1,
           labeller=labeller(subscribe=c("TRUE"="Subscribed",
                                         "FALSE"="Not Subscribed")))+
labs(title="Age Distribution by Newsletter Subscription Status",
     x="Age (in years)",
     y="Count")
# Out:
# plot without title

# %% [markdown]
# density plot

# %% [markdown]
# #### Visualization 3: Distribution of Played Hours by Subscription Status

# %%
ggplot(players, aes(x=played_hours, fill=subscribe))+
geom_histogram(bins=30, alpha=0.6, position="identity")+
labs(title="Distribution of Total Hours Played",
     x="Hours Played",
     y="Count",
     fill="Subscribed")

# Summary Statistics by Subscription
players|>
group_by(subscribe)|>
summarise(mean_hours=round(mean(played_hours),2),
          median_hours=round(median(played_hours),2), 
          n=n())|>
kable(caption="Played Hours by Subscription Status")
# Out:
# Table: Played Hours by Subscription Status
#
# |subscribe | mean_hours| median_hours|   n|
# |:---------|----------:|------------:|---:|
# |FALSE     |       0.50|          0.0|  52|
# |TRUE      |       7.78|          0.1| 144|
# plot without title

# %%
ggplot(players,
       aes(x=played_hours, fill=subscribe))+
geom_histogram(bins=30, alpha=0.9)+
facet_wrap(~subscribe, ncol=1,
           labeller=labeller(subscribe=c("TRUE"="Subscribed",
                                         "FALSE"="Not Subscribed")))+
labs(title="Distribution of Total Hours Played",
     x="Hours Played",
     y="Count")
# Out:
# plot without title

# %% [markdown]
# ##### This plot compares playtime distributions between subscribers and non-subscribers. If subscribers tend to play longer, playtime could be a useful predictor.

# %% [markdown]
# #### Visualization 4: Subscription Rate by Gender

# %%
# gender summary
gender_summary <- players|>
group_by(gender, subscribe)|>
summarise(count=n(), .groups='drop')|>
group_by(gender)|>
mutate(total=sum(count),
       percentage=count/total*100)

ggplot(gender_summary, aes(x=reorder(gender, total), y=count, fill=subscribe))+
geom_col(position="fill")+
coord_flip()+
labs(title="Subscription Rate by Gender",
     x="Gender",
     y="Percentage",
     fill="Subscribed")
# Out:
# plot without title

# %% [markdown]
# ##### Gender categories?

# %%
# VISUALIZATION: AGE VS PLAYED HOURS BY SUBSCRIPTION
ggplot(players|>filter(!is.na(Age)),
       aes(x=Age, y=played_hours, color=subscribe))+
geom_point(alpha=0.6, size=3)+
labs(title="Relationship between Age and Played Hours",
     x="Age (in years)",
     y="Hours Played",
     color="Subscribed")
# Out:
# plot without title

# %% [markdown]
# #### Methods and Plan
# Propose one method to address your question of interest using the selected dataset and explain why it was chosen. Do not perform any modelling or present results at this stage. We are looking for high-level planning regarding model choice and justifying that choice.
#
# In your explanation, respond to the following questions:
#
# Why is this method appropriate?
# Which assumptions are required, if any, to apply the method selected?
# What are the potential limitations or weaknesses of the method selected?
# How are you going to compare and select the model?
# How are you going to process the data to apply the model? For example: Are you splitting the data? How? How many splits? What proportions will you use for the splits? At what stage will you split? Will there be a validation set? Will you use cross validation?
#
# Proposed method: K-Nearest Neighbors (K-NN) Classification
# This method is appropriate because K-NN is well suited for predicting binary outcomes, which our response variable is that type. And K-NN can handle both categorical (experience, gender) and numeric (age, played_hours) variables. There is no strong assumptions, unlike regression, K-NN makes no assumptions about linear relationships or variable distributions. Interpretability, similar players likely have similar subscription behaviors.
# We are going to assume that all predictor variables should be relevant to subscription behavior. Sufficient sample size, need enough data points in each class for meaningful neighborhoods.
# Potential limitations could be the 4 predictor variables, we may face challenges if most are included. Sensitivity to K value. Imbalanced classes, if subscription rates are very high or low, model might be biased. Missing data. Categorical encoding, converting could lose information.
#
# Data Processing Plan:
# - Data Cleaning: address missing values, check for and handle any duplicate records, and verify all categorical levels are appropriate.
# - Convert
# - Data Splitting: training set, testing set, set random seed for reproducibility.
# - Scaling: standardize
# - Model Training and Selection: train KNN models with K values ranging, use cross-validation...
# - Model Evaluation
#
# Why not use validation set? Use cross-validation, why?
